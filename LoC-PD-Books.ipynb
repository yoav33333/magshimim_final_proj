# %% [markdown]
# https://huggingface.co/datasets/storytracer/LoC-PD-Books

# %%
import pandas as pd
temp = None
for i in range(1,8):
    df = pd.read_parquet(f"base_dbs/LoC-PD-Books/train_0000{i}.parquet")
    df["category"] = "book"
    temp = pd.concat([temp, df], ignore_index=True)
temp
# Out:
#              lccn                                              title  \
# 0        24024079                                     Faith at work,
# 1        17023956  Straws from the manager; or, Thoughts on Chris...
# 2     unk81039814                            A Christmas meditation.
# 3     unk81010574                                   Bethlehem bells.
# 4        09022920                                Christmas builders,
# ...           ...                                                ...
# 6803     24000553  Tribute to old Lancaster, city--county, Pennsy...
# 6804     01016609                               Lancaster townstead.
# 6805     07018194  An outline history of a church; a memorial of ...
# 6806     09012040            Lansdowne past and present, 1888. 1908.
# 6807     24015023  The history of St. John's Reformed Church, 185...
#
#                                    author  year  page_count  \
# 0     Trowbridge, Gertrude Mary (Sherman)  1924          88
# ...

# %%
temp = temp[['text', 'year', 'category']]
temp["decade"] = (temp["year"] // 10) * 10
temp
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_8176\3049691051.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   temp["decade"] = (temp["year"] // 10) * 10
#                                                    text  year category  decade
# 0     \n\n\n\nClass _ BN/'W *5 \n\nBook_ ‘AH _ \n\nC...  1924     book    1920
# 1     \nClass \n\nBook \n\n\n\nCOPYRIGHT DEPOSIE \n\...  1917     book    1910
# 2     . \n\n\n\n\nmm$ \n\n\n\nA CHIUSTMAS \nMEDITATI...  1916     book    1910
# 3     \n\n\nB V \n\n45 \n\n\n\n\n\nClass \n\nBook \n...  1912     book    1910
# 4     BV \n\n\n\n45 CHRISTMAS \n^^'^ BUILDERS \n\n\n...  1909     book    1900
# ...                                                 ...   ...      ...     ...
# ...

# %%
df = pd.read_parquet("large_dataset.parquet")
df = pd.concat([df, temp], ignore_index=True)
df.to_parquet("large_dataset.parquet")
df.head()
# Out:
#                                                 text    year category  decade
# 0  Republic Of Coi0atbid.---Wc publish observes i...  1825.0     None  1820.0
# 1  permit from ther owners, employers, or guard i...  1853.0     None  1850.0
# 2  Representatives Of the United States an Con-\n...  1867.0     None  1860.0
# 3  'csSei u icBai certainty COhccinin5 thc\n\ncha...  1862.0     None  1860.0
# 4  WIDENER HN BWGN X\n\nMYTHOLOGY FOR MODERNS JAM...  1899.0     None  1890.0

# %%
df.shape
# Out:
# (245730, 4)
