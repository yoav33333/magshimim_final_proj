# %%
import pandas as pd
temp = pd.read_csv("base_dbs/textage_large.csv")
temp.head()
# Out:
#                                                 text category  date  \
# 0  hEre begynneth the volume intituled and named ...     Book  1473
# 1  O P A I K L A K In three books The first leaf ...     Book  1473
# 2  quayersleyda partandin two yere aftyrlabouredn...     Book  1473
# 3  Iupiter andof the begynnyngandcomyng vp of Tro...     Book  1473
# 4  comyn w lehe wasrecomandedsolempnly andcalleda...     Book  1473
#
#                                                title          author  decade  \
# 0  hEre-begynneth-the-volume-intituled-and-named-...  william-caxton    1470
# 1  hEre-begynneth-the-volume-intituled-and-named-...  william-caxton    1470
# 2  hEre-begynneth-the-volume-intituled-and-named-...  william-caxton    1470
# 3  hEre-begynneth-the-volume-intituled-and-named-...  william-caxton    1470
# 4  hEre-begynneth-the-volume-intituled-and-named-...  william-caxton    1470
#
#    text_length
# 0         2890
# 1         2940
# 2         3116
# 3         3394
# 4         3338

# %%
temp["year"] = temp["date"].astype(int)
temp.drop(['title', 'text_length', 'author', 'date'], axis=1, inplace=True)
temp.head()
# Out:
#                                                 text category  decade  year
# 0  hEre begynneth the volume intituled and named ...     Book    1470  1473
# 1  O P A I K L A K In three books The first leaf ...     Book    1470  1473
# 2  quayersleyda partandin two yere aftyrlabouredn...     Book    1470  1473
# 3  Iupiter andof the begynnyngandcomyng vp of Tro...     Book    1470  1473
# 4  comyn w lehe wasrecomandedsolempnly andcalleda...     Book    1470  1473

# %%
df = pd.read_parquet("large_dataset.parquet")
df = pd.concat([df, temp], ignore_index=True)
df.to_parquet("large_dataset.parquet")
df.head()
# Out:
#    decade    year                                               text category
# 0  1470.0  1473.0  hEre begynneth the volume intituled and named ...     Book
# 1  1470.0  1473.0  O P A I K L A K In three books The first leaf ...     Book
# 2  1470.0  1473.0  quayersleyda partandin two yere aftyrlabouredn...     Book
# 3  1470.0  1473.0  Iupiter andof the begynnyngandcomyng vp of Tro...     Book
# 4  1470.0  1473.0  comyn w lehe wasrecomandedsolempnly andcalleda...     Book
