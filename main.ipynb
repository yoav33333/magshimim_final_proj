# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
# df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#                                                      text    year category  \
# 0       Republic Of Coi0atbid.---Wc publish observes i...  1825.0      NaN
# 1       permit from ther owners, employers, or guard i...  1853.0      NaN
# 2       Representatives Of the United States an Con-\n...  1867.0      NaN
# 3       'csSei u icBai certainty COhccinin5 thc\n\ncha...  1862.0      NaN
# 4       WIDENER HN BWGN X\n\nMYTHOLOGY FOR MODERNS JAM...  1899.0      NaN
# ...                                                   ...     ...      ...
# 153807  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...  1908.0     book
# 153808  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...  1901.0     book
# 153809  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...  1905.0     book
# 153810  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...  1908.0     book
# 153811  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...  1901.0     book
#
#         decade
# 0       1820.0
# 1       1850.0
# 2       1860.0
# 3       1860.0
# 4       1890.0
# ...        ...
# 153807  1900.0
# 153808  1900.0
# 153809  1900.0
# 153810  1900.0
# 153811  1900.0
#
# [153812 rows x 4 columns]

# %%
df.shape
# Out:
# (153812, 4)

# %%
import seaborn as sns
sns.histplot(data=df, x="decade", bins=range(1800, 2020, 10))
# Out:
# Matplotlib is building the font cache; this may take a moment.
# <Axes: xlabel='decade', ylabel='Count'>
