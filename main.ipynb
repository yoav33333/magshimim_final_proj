# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
# df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#                                                      text    year category  \
# 0       Republic Of Coi0atbid.---Wc publish observes i...  1825.0     None
# 1       permit from ther owners, employers, or guard i...  1853.0     None
# 2       Representatives Of the United States an Con-\n...  1867.0     None
# 3       'csSei u icBai certainty COhccinin5 thc\n\ncha...  1862.0     None
# 4       WIDENER HN BWGN X\n\nMYTHOLOGY FOR MODERNS JAM...  1899.0     None
# ...                                                   ...     ...      ...
# 245725  \nR 1 D D i. E \n\n\n\n\n\n\n\n\n^<Wt7^<^-t^-,...  1908.0     book
# 245726  # \n\n\n\n\n\nz^^-^ \n\n\n\nF 159 \n.L2 S5 \nC...  1901.0     book
# 245727  F 159 \n.L2 W6 \nCopy 1 \n\n\n\n\nThe 175th An...  1905.0     book
# 245728  \n\n\n\n\nXans^ownc \n\npast \n\n\n\nan6 \n\n\...  1908.0     book
# 245729  \nass. \n\n\n\nPRi:;sENTi:n r,Y \n\n\n\n-r- ' ...  1901.0     book
#
#         decade
# 0       1820.0
# 1       1850.0
# 2       1860.0
# 3       1860.0
# 4       1890.0
# ...        ...
# 245725  1900.0
# 245726  1900.0
# 245727  1900.0
# 245728  1900.0
# 245729  1900.0
#
# [245730 rows x 4 columns]

# %%
df.shape
# Out:
# (245730, 4)
