# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
# df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#                                                     text    year category  \
# 0      Republic Of Coi0atbid.---Wc publish observes i...  1825.0     None
# 1      permit from ther owners, employers, or guard i...  1853.0     None
# 2      Representatives Of the United States an Con-\n...  1867.0     None
# 3      'csSei u icBai certainty COhccinin5 thc\n\ncha...  1862.0     None
# 4      WIDENER HN BWGN X\n\nMYTHOLOGY FOR MODERNS JAM...  1899.0     None
# ...                                                  ...     ...      ...
# 55081  I'm at Hempstead Hair World in Elmont, NY http...  2016.0    tweet
# 55082  Bachelorette 💍💞 @ Laurita Winery https://t.co/...  2016.0    tweet
# 55083  When life gives you Lemon 🍋\nREAD 🤓🤓🤓👌👌👌☝️☝\n-...  2016.0    tweet
# 55084  This #job might be a great fit for you: Sr. In...  2016.0    tweet
# 55085  I'm at @PiazzaAvym in Canik, Samsun w/ @mertar...  2016.0    tweet
#
#        decade
# 0      1820.0
# 1      1850.0
# 2      1860.0
# 3      1860.0
# 4      1890.0
# ...       ...
# 55081  2010.0
# 55082  2010.0
# 55083  2010.0
# 55084  2010.0
# 55085  2010.0
#
# [55086 rows x 4 columns]

# %%
df.shape
# Out:
# (55086, 4)
