# %%
import pandas as pd
df = pd.DataFrame({"decade": [], "year": [], "text": [], "category": []})

# %%
df.to_parquet("large_dataset.parquet")

# %%
df = pd.read_parquet("large_dataset.parquet")
df
# Out:
#        decade    year                                               text  \
# 0      1470.0  1473.0  hEre begynneth the volume intituled and named ...
# 1      1470.0  1473.0  O P A I K L A K In three books The first leaf ...
# 2      1470.0  1473.0  quayersleyda partandin two yere aftyrlabouredn...
# 3      1470.0  1473.0  Iupiter andof the begynnyngandcomyng vp of Tro...
# 4      1470.0  1473.0  comyn w lehe wasrecomandedsolempnly andcalleda...
# ...       ...     ...                                                ...
# 91913  1920.0  1921.0  Yet I was disturbed to learn the facts and hav...
# 91914  1920.0  1921.0  do not know whe ther my mother is still alive ...
# 91915  1920.0  1921.0  a teacher of the Law Have you forgotten this b...
# 91916  1920.0  1921.0  him ask whether someone might be hiding her fr...
# 91917  1920.0  1921.0  BC THE ECLOGUES by Virgil ECLOGUE I MELIBOEUS ...
#
#       category
# 0         Book
# 1         Book
# 2         Book
# 3         Book
# 4         Book
# ...        ...
# 91913     Book
# 91914     Book
# 91915     Book
# 91916     Book
# 91917     Book
#
# [91918 rows x 4 columns]
